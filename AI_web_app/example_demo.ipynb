# %%
from api.example import ExampleAPI

# %%
from PIL import Image

# %%
api = ExampleAPI(font='resources/malgun.ttf')

# %%
result = api.query_text2text('안녕하세요')
result
# Out:
# '안녕하세요\nHAI is the best!!'

# %%
result = api.query_text2image('hello', (500, 200), bg_color=(60, 60, 60))
result
# Out:
# <PIL.Image.Image image mode=RGB size=500x200>

# %%
logo_image = Image.open('resources/logo.png')
logo_image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1604x802>

# %%
result = api.query_image2text(logo_image)
result
# Out:
# "Resolution: (1604, 802), InfoDict: {'srgb': 0, 'gamma': 0.45455, 'dpi': (143.99259999999998, 143.99259999999998)}"

# %%
result = api.query_image2image(logo_image)
result
# Out:
# <PIL.Image.Image image mode=L size=1604x802>
