# %%
from PIL import Image
from api.AI import AIAPI
from urllib import request

# %%
api = AIAPI()

# %%
img_file = "resources/demo_1.png"
Image.open(img_file)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=742x825>

# %%
img_bytes = open(img_file, "rb")
ocr_result = api.query_image2text(img_bytes)
print(ocr_result)
# Out:
# 2023 HAI 여름방학 Web APP 개발 과제
# 1. Text to Text API 활용
# · 텍스트를 입력받아 텍스트를 출력하는 API를 사용해 보겠습니다.
# . 텍스트를 입력하면 줄 바꿈과 HALis the best!! 를 추가해줍니다.
# Input Text
# 여기에 텍스트 입력
# API Output
# 여기에 텍스트 입력
# HAI is the best!!
# 2. Text to Image API 활용
# . 텍스트를 입력받아 이미지를 출력하는 API를 사용해 보겠습니다.
# . 입력된 텍스트가 그려진 비트맵 이미지가 생성됩니다.
# Input Text
# Hello. World!
# API Output
# Hello. World!

# %%
summarization_result = api.query_text2text(ocr_result)
title, summary = summarization_result
print("<제목>\n", title)
print("<요약>\n", summary)
# Out:
# <제목>
#  2023 HAI 여름방학 Web APP 개발 과제
# <요약>
#  1. Text to Text API를 사용하여 입력된 텍스트에 줄 바꿈과 "HAI is the best!!"를 추가하는 기능을 개발한다.
# 2. Text to Image API를 사용하여 입력된 텍스트로 그려진 비트맵 이미지를 생성하는 기능을 개발한다.
